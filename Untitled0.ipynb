# %% [markdown]
# <a href="https://colab.research.google.com/github/ParjitaMunshi/Machine-Learning/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras

# %%
def salary_model(y_new):
  xs = [0,1,2,3,4,5,6]
  ys = [0.5,0.6,0.7,0.8,0.9,1.0,1.1]
  model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])
  model.compile(optimizer="sgd", loss="mean_squared_error")
  model.fit(xs, ys, epochs=500)
  return model.predict(y_new)[0][0]

# %%
prediction = salary_model([8.0])
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 420ms/step - loss: 30.2238
# Epoch 2/500
# 1/1 [==============================] - 0s 6ms/step - loss: 15.9266
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 8.3943
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 4.4259
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 2.3352
# Epoch 6/500
# 1/1 [==============================] - 0s 4ms/step - loss: 1.2337
# Epoch 7/500
# 1/1 [==============================] - 0s 8ms/step - loss: 0.6533
# Epoch 8/500
# 1/1 [==============================] - 0s 7ms/step - loss: 0.3476
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 0.1864
# Epoch 10/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.1015
# Epoch 11/500
# 1/1 [==============================] - 0s 5ms/step - loss: 0.0567
# Epoch 12/500
# 1/1 [==============================] - 0s 4ms/step - loss: 0.0331
# ...

# %%
print(prediction*100,"thousand dollars")
# Out:
# 130.7565212249756 thousand dollars
